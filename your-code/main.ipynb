# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import seaborn as sns
import pylab as plt
import pandas as pd
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv(r'..\data\Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED

plt.bar(fitbit['Months_encoded'],height=fitbit.Steps)
plt.show()
# your code here

# %%
fitbit.groupby('Months_encoded').median().Steps.head()
# Out:
# Months_encoded
# 1    10366.0
# 2     9235.0
# 3    11122.0
# 4    13846.5
# 5    11998.0
# Name: Steps, dtype: float64

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
plt.bar(fitbit['Work_or_Weekend'],height=fitbit.Steps, width=0.1)
plt.show()
# your code here

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
for c in ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']:

    plt.scatter(x=fitbit[c], y=fitbit['Steps'])
    plt.xlabel("Minutes")
    plt.ylabel("Steps")
    plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv(r'..\data\titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['float','int']).columns
# your code here
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='object').columns
# your code here
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.figure(figsize=(12,6))

# %%
titanic['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'],cumulative=True)
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
for x in [10,20,30]:
    plt.hist(titanic['Age'],bins=x)
    plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""

Diferent Y axis values

"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.displot(titanic, x='Age')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.pie(titanic.Gender.value_counts(),labels=['Male','Female'])
plt.show()
# your code here

# %%
# Method 2 - seaborn
sns.countplot(titanic.Gender)
plt.show()
# your code here
# Out:
# C:\Users\Alberto\Anaconda3\envs\clase\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(titanic.Pclass, hue=titanic.Gender)
# Out:
# C:\Users\Alberto\Anaconda3\envs\clase\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
print(type(titanic.Age.describe()))
titanic.Age.describe()[1:].plot(kind='bar')
# Out:
# <class 'pandas.core.series.Series'>
# <AxesSubplot:>

# %%
plt.boxplot(titanic.Age)
plt.show()

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""

"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.displot(titanic.Age)
plt.figtext(0.6,0.5,str(titanic.Age.describe()))

plt.show()

# %%
sns.violinplot(titanic.Age)
plt.show()
# Out:
# C:\Users\Alberto\Anaconda3\envs\clase\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(x=titanic.Fare,y=titanic.Age)
# your code here

# %%
# Method 2 - seaborn
sns.scatterplot(x=titanic.Fare,y=titanic.Age)
# your code here
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
pd.plotting.scatter_matrix(titanic)
# Out:
# array([[<AxesSubplot:xlabel='PassengerId', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Survived', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Age', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Parch', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Fare', ylabel='PassengerId'>],
#        [<AxesSubplot:xlabel='PassengerId', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Age', ylabel='Survived'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Survived'>],
#        [<AxesSubplot:xlabel='PassengerId', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Pclass'>,
# ...

# %%
sns.heatmap(titanic.corr(method='pearson'), cmap="YlGnBu")
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Each column with itself
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
for x in titanic.Pclass.unique():

    plt.boxplot(titanic[titanic.Pclass==x].Age)
    plt.ylabel('Age')
    plt.figtext(0.6,0.5,'class: '+str(x))
    plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.FacetGrid(titanic, col='Gender')
