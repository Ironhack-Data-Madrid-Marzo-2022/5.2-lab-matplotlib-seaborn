# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')

# %%
fitbit.shape
# Out:
# (367, 24)

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED and WEEK_OR_WEEKEND
fitbit.groupby(['Months_encoded','Work_or_Weekend']).mean()['Steps'].unstack().plot(kind='bar', figsize=(12,4))
# save the figure in a folder called `figures` in your repo
# plt.savefig('../figures/average_steps_by_month_and_weekend.png')
# Out:
# <AxesSubplot:xlabel='Months_encoded'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %% [markdown]
# ## Challenge 2
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic['Age'].plot(kind='hist', bins=20)
# plt.savefig('../figures/age_distribution.png')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.subplot(1,3,1)
titanic['Age'].plot(kind='hist', bins=10)
plt.subplot(1,3,2)
titanic['Age'].plot(kind='hist', bins=20)
plt.subplot(1,3,3)
titanic['Age'].plot(kind='hist', bins=50)
# plt.savefig('../figures/age_distribution_subplots.png')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bin size affects the distribution of the data.
"""
# Out:
# '\nThe bin size affects the distribution of the data.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic['Age'], bins=20, color='blue',kde=True)
# plt.savefig('../figures/age_distribution_seaborn.png')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn

# %%
# Method 1 matplotlib
plt.pie(titanic.Gender.value_counts())
plt.savefig('../figures/matplot_gender.png')

# %%
# Method 2 - seaborn
sns.barplot(titanic.Gender.value_counts().index,titanic.Gender.value_counts().values)
plt.savefig('../figures/seaborn_gender.png')
# Out:
# C:\Users\Platermatter\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic['Pclass'].value_counts().plot.bar()
plt.savefig('../figures/Pclass.png')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic['Age'].describe()
titanic['Age'].describe().plot(kind='barh', figsize=(12,4))
plt.savefig('../figures/age_summary_statistics.png')

# %%
"""
The plot is a bar plot it shows the summary statistics of the feature 'Age'.
"""
# Out:
# "\nThe plot is a bar plot it shows the summary statistics of the feature 'Age'.\n"

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The plot tells us that the mean of the feature 'Age' is around 29.
"""
# Out:
# "\nThe plot tells us that the mean of the feature 'Age' is around 29.\n"

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
titanic['Age'].plot(kind='hist', bins=20)
plt.savefig('../figures/age_distribution.png')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The plot tells us that the distribution of the feature 'Age' is skewed to the right.
"""
# Out:
# "\nThe plot tells us that the distribution of the feature 'Age' is skewed to the right.\n"

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic['Fare'],titanic['Age'])
plt.savefig('../figures/matplot_fare_age.png')

# %%
# Method 2 - seaborn
sns.scatterplot(titanic['Fare'],titanic['Age'])
plt.savefig('../figures/seaborn_fare_age.png')
# Out:
# C:\Users\Platermatter\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr(), annot=True)
plt.savefig('../figures/correlation_matrix.png')

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are 'Fare with Survided' and 'SibSp and Parch'.
"""
# Out:
# "\nThe most correlated features are 'Fare with Survided' and 'SibSp and Parch'.\n"

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
titanic.groupby('Pclass').Age.describe()
titanic.groupby('Pclass').Age.describe().plot(kind='bar', figsize=(12,4))
plt.savefig('../figures/age_summary_statistics_Pclass.png')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.catplot(x='Age', y='Gender', data=titanic)
plt.savefig('../figures/distr_age_gender.png')
