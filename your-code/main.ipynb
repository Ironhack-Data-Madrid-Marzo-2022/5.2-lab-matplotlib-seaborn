# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import pylab as plt
import seaborn as sns


# Your Code Here
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)  
plt.rcParams['figure.figsize']=(12, 4)  # tamaño de los graficos por defecto

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv('../data/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# 5    2015-05-13             276    779      5.79      15            726.000
# 6    2015-05-14            2687   5614      4.17       2            782.000
# 7    2015-05-15            2793   8169      6.07      14            801.000
# 8    2015-05-16            4061  19971     14.84      18            532.000
# 9    2015-05-17            3349    852      6.33      12            606.000
# 10   2015-05-18            2961  11998      8.91      20            936.000
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
df=fitbit.groupby("Months_encoded").agg({"Steps":"mean"})





ax = sns.barplot(x="Months_encoded", y="Steps", data=fitbit)
plt.savefig("../figures/Months_encoded")

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
df= fitbit.groupby("Work_or_Weekend").agg({"Steps":"mean"})
sns.barplot(x="Work_or_Weekend", y="Steps", data=fitbit)
plt.savefig("../figures/Work_or_Weekend")

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
lista=["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]
for i in lista:
    fitbit.plot.scatter(x="Steps", y=i);
    plt.savefig("../figures/loop"+i)

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic= pd.read_csv('../data/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# 5               6       0.0       3
# 6               7       0.0       1
# 7               8       0.0       3
# 8               9       1.0       3
# 9              10       1.0       2
# 10             11       1.0       3
# 11             12       1.0       1
# 12             13       0.0       3
# 13             14       0.0       3
# 14             15       0.0       3
# 15             16       1.0       2
# 16             17       0.0       3
# 17             18       1.0       2
# 18             19       0.0       3
# 19             20       1.0       3
# 20             21       0.0       2
# 21             22       1.0       2
# 22             23       1.0       3
# 23             24       1.0       1
# 24             25       0.0       3
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
num_df=titanic.select_dtypes(include=[np.number])
num_df
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# 5               6       0.0       3  23.926502      0      0    8.4583
# 6               7       0.0       1  54.000000      0      0   51.8625
# 7               8       0.0       3   2.000000      3      1   21.0750
# 8               9       1.0       3  27.000000      0      2   11.1333
# 9              10       1.0       2  14.000000      1      0   30.0708
# 10             11       1.0       3   4.000000      1      1   16.7000
# 11             12       1.0       1  58.000000      0      0   26.5500
# ...

# %%
# CATEGORICAL VARIABLES
# your code here
num_df=titanic.select_dtypes(include=[object])
num_df
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# 5                                      Moran, Mr. James    male
# 6                               McCarthy, Mr. Timothy J    male
# 7                        Palsson, Master. Gosta Leonard    male
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                      Sandstrom, Miss. Marguerite Rut  female
# 11                             Bonnell, Miss. Elizabeth  female
# 12                       Saundercock, Mr. William Henry    male
# 13                          Andersson, Mr. Anders Johan    male
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
#sns.set(style='classic')
plt.style.use("classic")
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
ax = sns.histplot(x=titanic.Age,bins=200, color='b');

plt.savefig("../figures/Age_dist")

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
# your code here


colores=["b","r","y"]
bins_lista = [10,20,50]
for i,n in enumerate(bins_lista):
    plt.subplot(1, 3,(i+1))
    sns.histplot(x=titanic.Age, bins = n, color=colores[i])

plt.savefig("../figures/Age_dist_subplot")

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
Aumenta el detalle


"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.countplot(x=titanic.Age);
plt.savefig("../figures/Age_seaborn")

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
df = titanic.groupby("Gender").agg({"PassengerId": "count"})

plt.pie(df.PassengerId)
plt.savefig("../figures/Gender_matplotlib")

# %%
# Method 2 - seaborn
# your code here
ax = sns.histplot(x=titanic.Gender);
plt.savefig("../figures/Gender_seaborn")

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

ax = sns.histplot(x=titanic.Pclass,bins=5);
plt.savefig("../figures/Pclass_seaborn")

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(x=titanic.Age, color='y');
plt.savefig("../figures/Age_boxplot")

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

me da los percentiles 1,2,y 3.
los outlayers son aquellos que estan a mas de 1,5(q1-q3) del q2
"""
# Out:
# '\nyour comments here\n\nme da los percentiles 1,2,y 3.\nlos outlayers son aquellos que estan a mas de 1,5(q1-q3) del q2\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.histplot(x=titanic.Age,bins=50, color='b');
plt.figtext(0.15,0.4, titanic.Age.describe().to_string())
# Out:
# Text(0.15, 0.4, 'count    1309.000000\nmean       29.879186\nstd        13.448335\nmin         0.170000\n25%        22.000000\n50%        28.500000\n75%        37.000000\nmax        80.000000')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here


"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(x="Fare", y="Age", data = titanic)

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x="Fare", y="Age", data = titanic)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr=titanic.corr(method='pearson')

sns.set(style='white')   # estilo blanco


mascara=np.triu(np.ones_like(corr, dtype=bool))    # genera una mascara para la triangular superior


cmap=sns.diverging_palette(0, 10, as_cmap=True)    # paleta de colores

sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            center=0,
            square=True,
            linewidths=0.5,
            cbar_kws={'shrink':0.5}
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

Pclass and Fare
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
colores=["b","r","y"]

for i in range(3):
    df = titanic.loc[titanic.Pclass == i+1]
    sns.histplot(x=df.Age,bins=20, color=colores[i]);

# %%
colores=["b","r","y"]
for i in range(3):
    plt.subplot(1, 3,(i+1))
    df = titanic.loc[titanic.Pclass == i+1]
    sns.histplot(x=df.Age,bins=15, color=colores[i]);
    plt.figtext(0.15+0.3*i,0.4, df.Age.describe().to_string())

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
