# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
# Your Code Here
import pylab as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
df = pd.read_csv('../data/Fitbit2.csv')
df.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
df.columns
df.describe().T
# Out:
#                             count          mean          std      min  \
# Calorie burned              367.0   2741.501362   916.307036  179.000
# Steps                       367.0  10121.588556  5594.836225    0.000
# Distance                    367.0      8.549128     3.409881    0.000
# Floors                      367.0     11.724796    10.337370    0.000
# Minutes Sedentary           367.0    563.934482   294.793145    1.002
# Minutes Lightly Active      367.0    236.405995    86.531376    0.000
# Minutes Fairly Active       367.0     26.163488    20.319456    0.000
# Minutes Very Active         367.0     35.722071    31.006682    0.000
# Activity Calories           367.0   2044.147139  2041.267168    0.000
# MinutesOfSleep              367.0    290.479564   154.752328    0.000
# MinutesOfBeingAwake         367.0     28.008174    18.541415    0.000
# NumberOfAwakings            367.0     16.196185    10.757622    0.000
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
df_media_pasos_mes = df.groupby("Months_encoded").mean().reset_index()
df_media_pasos_mes.head()
# Out:
#    Months_encoded  Calorie burned         Steps   Distance     Floors  \
# 0               1     2812.806452   9892.064516   7.912581   8.580645
# 1               2     2600.100000   8922.866667   7.143667   9.666667
# 2               3     2281.258065  10312.935484   9.184194   9.935484
# 3               4     3030.800000  13079.033333  11.190667  11.566667
# 4               5     2836.580645  10620.096774   8.799677  10.741935
#
#    Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# 0         573.702000              249.838710              27.548387
# 1         598.077133              214.933333              25.166667
# 2         490.865000              220.935484              13.096774
# 3         638.469700              293.866667              13.800000
# 4         654.149161              229.580645              28.258065
#
#    Minutes Very Active  Activity Calories  ...  MinutesOfBeingAwake  \
# ...

# %% [markdown]
# En la siguiente celda utilizo plt.bar para hacer un gráfico de barras, el primer argumento serán los valores de x (eje horizontal) el segundo argumento son los valores de y (eje vertical)

# %%
# AVERAGE STEPS BY MONTH_ENCODED

plt.bar(df_media_pasos_mes["Months_encoded"], df_media_pasos_mes["Steps"]) #utilizo plt.bar para hacer un gráfico de barras, el primer argumento serán los valores de x (eje horizontal) el segundo argumento son los valores de y (eje vertical)
plt.xlabel("Months")#Pongo nombre al eje x "Month"
plt.ylabel("Steps")#Pongo nombre al eje y "steps"
plt.rcParams['figure.figsize']=(12, 4) #defino el tamaño de la figura (ancho , alto)
plt.title("Superplot");#Para poner el titulo al grafico

# %%
df[(df["Months_encoded"]==3)]["Steps"].mean() #compruebo la media de pasos en marzo para ver si cuadra
# Out:
# 10312.935483870968

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# months= df["Months_encoded"]

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
x = step
y = cambia(1º lightly 2º very, 3ºsedent)

plt.subplot(1, 2, posicion_cambia)
plt.plot(x,y)

# %%
#sin bucle 
plot Lightly Active vs Steps
plt.hist(df_media_pasos_mes["Months_encoded"], df_media_pasos_mes["Steps"])

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
