# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np

import pylab as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit.columns=[e.lower().replace(' ','_') for e in fitbit.columns]

fitbit
# Out:
#            date  calorie_burned  steps  distance  floors  minutes_sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
plt.rcParams['figure.figsize']=(12, 4)  # tamaño de los graficos por defecto

# %%
steps_month = fitbit.groupby('months_encoded').agg({'steps':'mean'})

steps_month
# Out:
#                        steps
# months_encoded
# 1                9892.064516
# 2                8922.866667
# 3               10312.935484
# 4               13079.033333
# 5               10620.096774
# 6               12536.166667
# 7                9193.322581
# 8               11584.774194
# 9                9191.333333
# 10               8272.451613
# 11               9467.466667
# 12               8470.064516

# %%
steps_month.plot.bar();
plt.savefig('../figures/mean_steps')

# %%
sns.barplot(data=fitbit, x='months_encoded', y = 'steps')
plt.savefig('../figures/mean_steps2')

# %%
sns.barplot(data=fitbit, x='work_or_weekend', y = 'steps')
plt.savefig('../figures/days_steps')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
plots = ['minutes_sedentary', 'minutes_lightly_active', 'minutes_very_active']

for i in plots:
    fitbit.plot.scatter(x='steps', y=i);
    plt.savefig('../figures/'+i)

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic.columns=[e.lower().replace(' ','_') for e in titanic.columns]

titanic
# Out:
#       passengerid  survived  pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    name  gender        age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# passengerid      int64
# survived       float64
# pclass           int64
# name            object
# gender          object
# age            float64
# sibsp            int64
# parch            int64
# ticket          object
# fare           float64
# cabin           object
# embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.select_dtypes(include=(np.number))
# Out:
#       passengerid  survived  pclass        age  sibsp  parch      fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
titanic.select_dtypes(include=['int', 'float'])
# Out:
#       passengerid  survived  pclass        age  sibsp  parch      fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
titanic.select_dtypes(include='object')
# Out:
#                                                    name  gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   ticket cabin embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.age);
plt.savefig('../figures/titanic_age')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
sns.histplot(x=titanic.age);
plt.savefig('../figures/age')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
colores = ['r', 'g', 'y']

for i, e in enumerate([10, 20, 50]):
    plt.subplot(1, 3, (i+1))
    sns.histplot(x=titanic.age, bins=e, color=colores[i]);
    
plt.savefig('../figures/ages')

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.countplot(x=titanic.age, 
              palette='gist_rainbow');
plt.savefig('../figures/ages2')

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
tab=titanic.groupby('gender').agg({'pclass': 'count'})

tab
# Out:
#         pclass
# gender
# female     466
# male       843

# %%
plt.pie(tab.pclass)


plt.pie(tab.pclass, 

        colors=['b', 'orange'],
        startangle=90,
        autopct='%1.f%%')


plt.title('Porcentaje por genero');

plt.savefig('../figures/pie_gender')

# %%
sns.histplot(x=titanic.gender);
plt.savefig('../figures/gender')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.pclass, 
              palette='gist_rainbow');
plt.savefig('../figures/ages2')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x=titanic.age, color='r');
plt.savefig('../figures/ages_summary')

# %%
sns.violinplot(data=titanic.age, color='orange');
plt.savefig('../figures/ages_violin')

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
# El 50% de las edades esta en 22 y 37 años, el mínimo es 0 y el maximo 80, la varianza entorno al 28,5 años.

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.age, bins=50);

plt.figtext(0.60,0.5, titanic.age.describe().to_string())

plt.savefig('../figures/summary_age')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
La media, desviación típica, la cantidad y como está distribuida

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.plot.scatter(x='fare', y='age');

# %%
sns.scatterplot(x='fare', y='age', data=titanic);

plt.savefig('../figures/fare_age')

# %%
plt.scatter(x='fare', y='age', data=titanic);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
pd.plotting.scatter_matrix(titanic, 
                           alpha=0.8, # transparencia
                           figsize=(8, 8),   # tamaño de la figura
                           diagonal='kde'
                          );

# %%
corr=titanic.corr(method='pearson')


sns.set(style='white')   # estilo blanco


mascara=np.triu(np.ones_like(corr, dtype=bool))    # genera una mascara para la triangular superior


cmap=sns.diverging_palette(0, 10, as_cmap=True)    # paleta de colores

sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            center=0,
            square=True,
            linewidths=0.5,
            cbar_kws={'shrink':0.5}
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
Fare con pclass

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.histplot(x=titanic.age, hue=titanic.pclass);

# %%
colores=["b","r","y"]
for i in range(3):
    plt.subplot(1, 3,(i+1))
    df = titanic.loc[titanic.pclass == i+1]
    sns.histplot(x=df.age,bins=15, color=colores[i]);
    plt.figtext(0.15+0.3*i,0.95, df.age.describe().to_string())

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.histplot(x=titanic.age, hue=titanic.gender);
